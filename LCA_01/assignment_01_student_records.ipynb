# %%
student_record_dict = {
    "Student 01": {
        "Roll Number": 1272261125,
        "Name": "Advaet Chintakunta",
        "Branch": "Computer Science & Engineering",
        "Marks": (98, 99, 66),
    },
    "Student 02": {
        "Roll Number": 1272261126,
        "Name": "Samarth Dombe",
        "Branch": "Computer Science & Engineering",
        "Marks": (94, 93, 96),
    },
    "Student 03": {
        "Roll Number": 1272261127,
        "Name": "Rohit Manglani",
        "Branch": "Computer Science & Engineering",
        "Marks": (98, 99, 99),
    },
}

student_record_dict["Student 04"] = {
    "Roll Number": 1272261128,
    "Name": "Atharva Patil",
    "Branch": "Information Technology",
    "Marks": (91, 92, 95),
}

del student_record_dict["Student 02"]

student_record_dict["Student 03"]["Branch"] = "Artificial Intelligence & Data Science"

student_record_list = list(student_record_dict.keys())

for key in student_record_list:
    student = student_record_dict[key]
    print(f"Serial  No. : {key}")
    print(f"PRN         : {student['Roll Number']}")
    print(f"Name        : {student['Name']}")
    print(f"Branch      : {student['Branch']}")
    print(f"Marks       : {student['Marks']}")
    print("\n")
